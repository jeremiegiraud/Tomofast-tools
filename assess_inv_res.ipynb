# %%
# Cell 1: Imports
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

# Import the module
import costs_vis as cv

# %%
# Get the cost file
pth_output = './Tomofast-x/output/sw_wa/model_ausmoho_2/'
filename_costs = pth_output + 'costs.txt'

cv.main(filename_costs)
